# %%
import pandas as pd
x=pd.DataFrame({"Name":["Alice","Bob","Charlie","Diana","Ethan"],
                "Age":[28,34,25,42,30],
                "Salary":[70000,80000,50000,110000,75000]})
print(x)
# Out:
#       Name  Age  Salary
# 0    Alice   28   70000
# 1      Bob   34   80000
# 2  Charlie   25   50000
# 3    Diana   42  110000
# 4    Ethan   30   75000

# %%
x["Tax"]=x["Salary"]*0.2
print(x)
# Out:
#       Name  Age  Salary      Tax
# 0    Alice   28   70000  14000.0
# 1      Bob   34   80000  16000.0
# 2  Charlie   25   50000  10000.0
# 3    Diana   42  110000  22000.0
# 4    Ethan   30   75000  15000.0

# %%
print(x[x["Age"]>=30])
# Out:
#     Name  Age  Salary      Tax
# 1    Bob   34   80000  16000.0
# 3  Diana   42  110000  22000.0
# 4  Ethan   30   75000  15000.0

# %%
y=x[x["Age"]<30]
print(y["Salary"].mean())
# Out:
# 60000.0

# %%
print(x.sort_values(by="Salary",ascending=False))
# Out:
#       Name  Age  Salary      Tax
# 3    Diana   42  110000  22000.0
# 1      Bob   34   80000  16000.0
# 4    Ethan   30   75000  15000.0
# 0    Alice   28   70000  14000.0
# 2  Charlie   25   50000  10000.0
